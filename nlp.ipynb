# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv('./Cleaned Data/cleaned_data.csv')

# %%
df
# Out:
#     Issue Type       Status  Priority  \
# 0        Story         Done  Critical
# 1         Task         Done     Major
# 2          Bug         Done  Critical
# 3         Task         Done     Major
# 4         Task           QA  Critical
# ..         ...          ...       ...
# 860    Subtask         Done     Major
# 861    Subtask         Done     Major
# 862    Subtask  In Progress     Major
# 863    Subtask         Done     Major
# 864    Subtask         Done     Major
#
#                                                Summary  \
# 0    When my session expires I should be taken to l...
# 1    Update the payment config to only have mapping...
# 2    The wrong date is showing up on payouts and or...
# 3                            Rename Sparks and Signals
# 4                          Create basic WeOS Slack App
# ..                                                 ...
# 860              Add a form for creating a vendor item
# 861    Add command receiver and endpoint for creati...
# 862    Update the expense form to show list of rela...
# 863                       Add form for editing invoice
# 864                Hook up editing vendor quote screen
#
#      Original Time Estimated  Total Time Spent
# 0                         60                60
# 1                         30                30
# 2                         30                38
# 3                         30                30
# 4                          0               240
# ..                       ...               ...
# 860                      120                60
# 861                      120                60
# 862                      120               390
# 863                      120                40
# 864                       60                60
#
# [865 rows x 6 columns]

# %%
text_features = ['Summary']
categorical_features = ['Issue Type', 'Priority']
numeric_features = ['Original Time Estimated']
target = 'Total Time Spent'  # Assuming the 7th column is your target

# %%
X = df[text_features + categorical_features + numeric_features]
y = df[target]

# %%
tfidf_vectorizer = TfidfVectorizer()
one_hot_encoder = OneHotEncoder(handle_unknown='ignore')

# %%
#combine all features
preprocessor = ColumnTransformer(
    transformers=[
        ('text', tfidf_vectorizer, 'Summary'),  # Pass a string, not list
        ('cat', one_hot_encoder, categorical_features),
        ('num', 'passthrough', numeric_features)
    ]
)

# %%
# Build and train model
model = make_pipeline(preprocessor, LinearRegression())

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('text', TfidfVectorizer(),
#                                                   'Summary'),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Issue Type', 'Priority']),
#                                                  ('num', 'passthrough',
#                                                   ['Original Time '
#                                                    'Estimated'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Absolute Error: 416.69

# %%
print("Predictions:", y_pred)
print("Actual:", y_test.values)
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Predictions: [  205.41214738 -2051.60916157   279.8509158    100.35789556
#    166.07709616  -283.93985141  -197.0882158    825.62715028
#     75.17615687  -214.29789144   411.48739241   -65.3912238
#   -155.6653233      3.54750206   603.55288298   556.13163357
#    516.57062536   727.06942627   -48.78402395     8.18403964
#    663.89661582   316.08468981   285.23721018   -75.9291277
#    265.23200766   794.12778585 -1042.02259096  -481.52229285
#      6.61770299   275.83790346   527.13724751  -577.46546361
#    142.40099297   373.20431871  -294.48573914  -860.87526483
#    -50.00170977   190.28046661    17.79062598   239.9608193
#    263.10978447  -332.07209668  -258.95744759  -262.26208485
#    427.6199205     82.79352096   464.00114425  -378.78252515
#    222.56249076   248.63061542   108.81783446  -715.40372172
#    444.05682075   633.57715812   149.68327603    73.47435204
#    843.33625936  -665.74283659  -200.31713938   133.06212155
#    417.31301249   389.67637426   729.96053774  -244.33298002
#    319.96889943   566.19468429    47.18850013  1102.71044038
#   -255.64293097   -68.66098798   322.31239073   407.75922919
